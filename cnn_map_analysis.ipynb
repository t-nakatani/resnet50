# %%
import tensorflow as tf
model = tf.keras.models.load_model('../data/weight/resnet50.h5')

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image

# %%
img = image.load_img('../data/dataset/natural_img2/natural2/0_0.png', target_size=(32, 32))
x_orig = image.img_to_array(img)  # ndarray: (224, 224, 3), float32
x = np.expand_dims(x_orig, axis=0)  # ndarray: (1, 224, 224, 3), float32

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7F99743F5550>

# %%
pred = model.predict(sample_pred_images, batch_size=None, verbose=0, steps=None)
# y_pred = model.predict(x)
# Out:
# (1, 32, 32, 3)
